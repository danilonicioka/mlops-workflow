# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Average

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

def extract_and_plot_average(directory):
    """
    Extracts the 'Average' column from all CSV files in the given directory
    and plots the values in a graph with differentiation for each file.
    
    Args:
        directory (str): Path to the directory containing CSV files.
    """
    plt.figure(figsize=(12, 8))  # Create a larger figure for better visualization

    # Iterate through all files in the directory
    for file in os.listdir(directory):
        if file.endswith(".csv"):
            file_path = os.path.join(directory, file)
            try:
                # Read the CSV file
                df = pd.read_csv(file_path)

                # Check if 'Average' column exists
                if 'Average' in df.columns:
                    # Plot the data with a label for the file name
                    plt.plot(
                        df['Average'].tolist(),
                        marker='o',  # Marker for points
                        linestyle='-',  # Line style
                        label=file  # Legend label for the file
                    )
                else:
                    print(f"'Average' column not found in {file}")
            except Exception as e:
                print(f"Error reading {file}: {e}")

    # Add graph details
    plt.title("Average Values from Multiple CSV Files", fontsize=16)
    plt.xlabel("Index", fontsize=14)
    plt.ylabel("Average Value", fontsize=14)
    plt.legend(title="File Source", loc="best", fontsize=12)  # Add legend
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Example usage
directory_path = "results/csv"
extract_and_plot_average(directory_path)

# %% [markdown]
# # Requests and Replicas

# %%
# Load the data into a pandas DataFrame
file_path = 'test1_P2_I1.csv'
df = pd.read_csv(file_path)

# Extract the columns representing response times (all columns except the first and last)
response_columns = df.columns[1:-1]  # Exclude the first (replica) and last (average) columns
response_values = df[response_columns]

# Plot each request's response time (excluding the replica and average columns)
plt.figure(figsize=(10, 6))
for replica in range(30):
    plt.plot(range(1, 1 + len(response_values.iloc[replica])), response_values.iloc[replica], marker='o', label=f'Replica {replica+1}')

# Add labels and title
plt.xlabel('Request')
plt.ylabel('Response Time')
plt.title('Response Time for Each Request and Replica')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
rows_with_less_variation = []
    
for i in range(30):
    # Calculate the standard deviation of the row
    std_dev = np.std(response_values.iloc[i])
    print("replica", i+1, ":", std_dev)

    # If standard deviation is above a threshold, keep the row
    if std_dev < 3:  # Set your threshold here
        rows_with_less_variation.append(i)
# Out:
# replica 1 : 2.994861904044137
# replica 2 : 3.0167802061262132
# replica 3 : 2.4593337298726423
# replica 4 : 2.9933439042007146
# replica 5 : 1.879126250392059
# replica 6 : 2.2629673306285625
# replica 7 : 2.7815016232082796
# replica 8 : 2.696172509253168
# replica 9 : 2.9925852555702668
# replica 10 : 3.1555074069046922
# replica 11 : 3.2294121986801434
# replica 12 : 2.5322587278047903
# replica 13 : 2.9027456964038265
# replica 14 : 2.4630528949441457
# replica 15 : 2.9010441690260103
# replica 16 : 2.0253677480885752
# replica 17 : 2.321561400585719
# replica 18 : 3.0323573109826136
# replica 19 : 3.0223792866460184
# replica 20 : 2.8261102915363883
# replica 21 : 3.2420398656099163
# replica 22 : 2.8159756980446433
# replica 23 : 2.3678668834999783
# replica 24 : 2.9108499857342576
# replica 25 : 3.1822130686722776
# replica 26 : 2.394953970881053
# replica 27 : 2.6522213675700352
# replica 28 : 2.9085745383980584
# replica 29 : 2.780560934118713
# replica 30 : 2.744505162251013

# %%
# Plot each request's response time (excluding the replica and average columns)
plt.figure(figsize=(10, 6))
for replica in rows_with_less_variation:
    plt.plot(range(1, 1 + len(response_values.iloc[replica])), response_values.iloc[replica], marker='o', label=f'Replica {replica+1}')

# Add labels and title
plt.xlabel('Request')
plt.ylabel('Response Time')
plt.title('Response Time for Each Request and Replica')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Load the data into a pandas DataFrame
file_path = 'test2_P3_I1.csv'
df = pd.read_csv(file_path)

# Extract the columns representing response times (all columns except the first and last)
response_columns = df.columns[1:-1]  # Exclude the first (replica) and last (average) columns
response_values = df[response_columns]

# Plot each request's response time (excluding the replica and average columns)
plt.figure(figsize=(10, 6))
for replica in range(30):
    plt.plot(range(1, 1 + len(response_values.iloc[replica])), response_values.iloc[replica], marker='o', label=f'Replica {replica+1}')

# Add labels and title
plt.xlabel('Request')
plt.ylabel('Response Time')
plt.title('Response Time for Each Request and Replica')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Load the data into a pandas DataFrame
file_path = 'test3_P12_I1.csv'
df = pd.read_csv(file_path)

# Extract the columns representing response times (all columns except the first and last)
response_columns = df.columns[1:-1]  # Exclude the first (replica) and last (average) columns
response_values = df[response_columns]

# Plot each request's response time (excluding the replica and average columns)
plt.figure(figsize=(10, 6))
for replica in range(30):
    plt.plot(range(1, 1 + len(response_values.iloc[replica])), response_values.iloc[replica], marker='o', label=f'Replica {replica+1}')

# Add labels and title
plt.xlabel('Request')
plt.ylabel('Response Time')
plt.title('Response Time for Each Request and Replica')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Load the data into a pandas DataFrame
file_path = 'test4_P2_I4.csv'
df = pd.read_csv(file_path)

# Extract the columns representing response times (all columns except the first and last)
response_columns = df.columns[1:-1]  # Exclude the first (replica) and last (average) columns
response_values = df[response_columns]

# Plot each request's response time (excluding the replica and average columns)
plt.figure(figsize=(10, 6))
for replica in range(30):
    plt.plot(range(1, 1 + len(response_values.iloc[replica])), response_values.iloc[replica], marker='o', label=f'Replica {replica+1}')

# Add labels and title
plt.xlabel('Request')
plt.ylabel('Response Time')
plt.title('Response Time for Each Request and Replica')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Load the data into a pandas DataFrame
file_path = 'test5_P3_I4.csv'
df = pd.read_csv(file_path)

# Extract the columns representing response times (all columns except the first and last)
response_columns = df.columns[1:-1]  # Exclude the first (replica) and last (average) columns
response_values = df[response_columns]

# Plot each request's response time (excluding the replica and average columns)
plt.figure(figsize=(10, 6))
for replica in range(30):
    plt.plot(range(1, 1 + len(response_values.iloc[replica])), response_values.iloc[replica], marker='o', label=f'Replica {replica+1}')

# Add labels and title
plt.xlabel('Request')
plt.ylabel('Response Time')
plt.title('Response Time for Each Request and Replica')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Load the data into a pandas DataFrame
file_path = 'test6_P12_I4.csv'
df = pd.read_csv(file_path)

# Extract the columns representing response times (all columns except the first and last)
response_columns = df.columns[1:-1]  # Exclude the first (replica) and last (average) columns
response_values = df[response_columns]

# Plot each request's response time (excluding the replica and average columns)
plt.figure(figsize=(10, 6))
for replica in range(30):
    plt.plot(range(1, 1 + len(response_values.iloc[replica])), response_values.iloc[replica], marker='o', label=f'Replica {replica+1}')

# Add labels and title
plt.xlabel('Request')
plt.ylabel('Response Time')
plt.title('Response Time for Each Request and Replica')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Load the data into a pandas DataFrame
file_path = 'test7_P2_I6.csv'
df = pd.read_csv(file_path)

# Extract the columns representing response times (all columns except the first and last)
response_columns = df.columns[1:-1]  # Exclude the first (replica) and last (average) columns
response_values = df[response_columns]

# Plot each request's response time (excluding the replica and average columns)
plt.figure(figsize=(10, 6))
for replica in range(30):
    plt.plot(range(1, 1 + len(response_values.iloc[replica])), response_values.iloc[replica], marker='o', label=f'Replica {replica+1}')

# Add labels and title
plt.xlabel('Request')
plt.ylabel('Response Time')
plt.title('Response Time for Each Request and Replica')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Load the data into a pandas DataFrame
file_path = 'test8_P3_I6.csv'
df = pd.read_csv(file_path)

# Extract the columns representing response times (all columns except the first and last)
response_columns = df.columns[1:-1]  # Exclude the first (replica) and last (average) columns
response_values = df[response_columns]

# Plot each request's response time (excluding the replica and average columns)
plt.figure(figsize=(10, 6))
for replica in range(30):
    plt.plot(range(1, 1 + len(response_values.iloc[replica])), response_values.iloc[replica], marker='o', label=f'Replica {replica+1}')

# Add labels and title
plt.xlabel('Request')
plt.ylabel('Response Time')
plt.title('Response Time for Each Request and Replica')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Load the data into a pandas DataFrame
file_path = 'test9_P12_I6.csv'
df = pd.read_csv(file_path)

# Extract the columns representing response times (all columns except the first and last)
response_columns = df.columns[1:-1]  # Exclude the first (replica) and last (average) columns
response_values = df[response_columns]

# Plot each request's response time (excluding the replica and average columns)
plt.figure(figsize=(10, 6))
for replica in range(30):
    plt.plot(range(1, 1 + len(response_values.iloc[replica])), response_values.iloc[replica], marker='o', label=f'Replica {replica+1}')

# Add labels and title
plt.xlabel('Request')
plt.ylabel('Response Time')
plt.title('Response Time for Each Request and Replica')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
