# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load the data into a pandas DataFrame
file_path = 'test1P2I1.csv'
df = pd.read_csv(file_path)

# Extract the columns representing response times (all columns except the first and last)
response_columns = df.columns[1:-1]  # Exclude the first (replica) and last (average) columns
response_values = df[response_columns]

# Plot each request's response time (excluding the replica and average columns)
plt.figure(figsize=(10, 6))
for replica in range(30):
    plt.plot(range(1, 1 + len(response_values.iloc[replica])), response_values.iloc[replica], marker='o', label=f'Replica {replica+1}')

# Add labels and title
plt.xlabel('Request')
plt.ylabel('Response Time')
plt.title('Response Time for Each Request and Replica')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
rows_with_less_variation = []
    
for i in range(30):
    # Calculate the standard deviation of the row
    std_dev = np.std(response_values.iloc[i])
    print("replica", i+1, ":", std_dev)

    # If standard deviation is above a threshold, keep the row
    if std_dev < 3:  # Set your threshold here
        rows_with_less_variation.append(i)
# Out:
# replica 1 : 2.988834729991518
# replica 2 : 2.342056949295303
# replica 3 : 2.6414820150383047
# replica 4 : 2.569907370965481
# replica 5 : 2.73924903738351
# replica 6 : 2.386511014239392
# replica 7 : 2.4028617261946508
# replica 8 : 2.0894265118680786
# replica 9 : 2.7539459026221182
# replica 10 : 2.667904702364751
# replica 11 : 2.5730584397299205
# replica 12 : 2.6684722468186517
# replica 13 : 2.0114415456144354
# replica 14 : 2.9171064115205834
# replica 15 : 2.7747017459596144
# replica 16 : 2.4930523263286393
# replica 17 : 2.1276614164432073
# replica 18 : 4.38033873192216
# replica 19 : 2.504418435422745
# replica 20 : 3.252437448600615
# replica 21 : 2.710967007602419
# replica 22 : 3.185672046874465
# replica 23 : 2.6887298106431228
# replica 24 : 2.88778004397374
# replica 25 : 2.909697428892904
# replica 26 : 2.9355302202610507
# replica 27 : 2.769773117049991
# replica 28 : 2.9614310796197487
# replica 29 : 3.110617088100217
# replica 30 : 2.4105226034113256

# %%
# Plot each request's response time (excluding the replica and average columns)
plt.figure(figsize=(10, 6))
for replica in rows_with_less_variation:
    plt.plot(range(1, 1 + len(response_values.iloc[replica])), response_values.iloc[replica], marker='o', label=f'Replica {replica+1}')

# Add labels and title
plt.xlabel('Request')
plt.ylabel('Response Time')
plt.title('Response Time for Each Request and Replica')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Load the data into a pandas DataFrame
file_path = 'test2P3I1.csv'
df = pd.read_csv(file_path)

# Extract the columns representing response times (all columns except the first and last)
response_columns = df.columns[1:-1]  # Exclude the first (replica) and last (average) columns
response_values = df[response_columns]

# Plot each request's response time (excluding the replica and average columns)
plt.figure(figsize=(10, 6))
for replica in range(30):
    plt.plot(range(1, 1 + len(response_values.iloc[replica])), response_values.iloc[replica], marker='o', label=f'Replica {replica+1}')

# Add labels and title
plt.xlabel('Request')
plt.ylabel('Response Time')
plt.title('Response Time for Each Request and Replica')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Load the data into a pandas DataFrame
file_path = 'test3P12I1.csv'
df = pd.read_csv(file_path)

# Extract the columns representing response times (all columns except the first and last)
response_columns = df.columns[1:-1]  # Exclude the first (replica) and last (average) columns
response_values = df[response_columns]

# Plot each request's response time (excluding the replica and average columns)
plt.figure(figsize=(10, 6))
for replica in range(30):
    plt.plot(range(1, 1 + len(response_values.iloc[replica])), response_values.iloc[replica], marker='o', label=f'Replica {replica+1}')

# Add labels and title
plt.xlabel('Request')
plt.ylabel('Response Time')
plt.title('Response Time for Each Request and Replica')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Load the data into a pandas DataFrame
file_path = 'test4P2I4.csv'
df = pd.read_csv(file_path)

# Extract the columns representing response times (all columns except the first and last)
response_columns = df.columns[1:-1]  # Exclude the first (replica) and last (average) columns
response_values = df[response_columns]

# Plot each request's response time (excluding the replica and average columns)
plt.figure(figsize=(10, 6))
for replica in range(30):
    plt.plot(range(1, 1 + len(response_values.iloc[replica])), response_values.iloc[replica], marker='o', label=f'Replica {replica+1}')

# Add labels and title
plt.xlabel('Request')
plt.ylabel('Response Time')
plt.title('Response Time for Each Request and Replica')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Load the data into a pandas DataFrame
file_path = 'test5P3I4.csv'
df = pd.read_csv(file_path)

# Extract the columns representing response times (all columns except the first and last)
response_columns = df.columns[1:-1]  # Exclude the first (replica) and last (average) columns
response_values = df[response_columns]

# Plot each request's response time (excluding the replica and average columns)
plt.figure(figsize=(10, 6))
for replica in range(30):
    plt.plot(range(1, 1 + len(response_values.iloc[replica])), response_values.iloc[replica], marker='o', label=f'Replica {replica+1}')

# Add labels and title
plt.xlabel('Request')
plt.ylabel('Response Time')
plt.title('Response Time for Each Request and Replica')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Load the data into a pandas DataFrame
file_path = 'test6P12I4.csv'
df = pd.read_csv(file_path)

# Extract the columns representing response times (all columns except the first and last)
response_columns = df.columns[1:-1]  # Exclude the first (replica) and last (average) columns
response_values = df[response_columns]

# Plot each request's response time (excluding the replica and average columns)
plt.figure(figsize=(10, 6))
for replica in range(30):
    plt.plot(range(1, 1 + len(response_values.iloc[replica])), response_values.iloc[replica], marker='o', label=f'Replica {replica+1}')

# Add labels and title
plt.xlabel('Request')
plt.ylabel('Response Time')
plt.title('Response Time for Each Request and Replica')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Load the data into a pandas DataFrame
file_path = 'test7P2I6.csv'
df = pd.read_csv(file_path)

# Extract the columns representing response times (all columns except the first and last)
response_columns = df.columns[1:-1]  # Exclude the first (replica) and last (average) columns
response_values = df[response_columns]

# Plot each request's response time (excluding the replica and average columns)
plt.figure(figsize=(10, 6))
for replica in range(30):
    plt.plot(range(1, 1 + len(response_values.iloc[replica])), response_values.iloc[replica], marker='o', label=f'Replica {replica+1}')

# Add labels and title
plt.xlabel('Request')
plt.ylabel('Response Time')
plt.title('Response Time for Each Request and Replica')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Load the data into a pandas DataFrame
file_path = 'test8P3I6.csv'
df = pd.read_csv(file_path)

# Extract the columns representing response times (all columns except the first and last)
response_columns = df.columns[1:-1]  # Exclude the first (replica) and last (average) columns
response_values = df[response_columns]

# Plot each request's response time (excluding the replica and average columns)
plt.figure(figsize=(10, 6))
for replica in range(30):
    plt.plot(range(1, 1 + len(response_values.iloc[replica])), response_values.iloc[replica], marker='o', label=f'Replica {replica+1}')

# Add labels and title
plt.xlabel('Request')
plt.ylabel('Response Time')
plt.title('Response Time for Each Request and Replica')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Load the data into a pandas DataFrame
file_path = 'test9P12I6.csv'
df = pd.read_csv(file_path)

# Extract the columns representing response times (all columns except the first and last)
response_columns = df.columns[1:-1]  # Exclude the first (replica) and last (average) columns
response_values = df[response_columns]

# Plot each request's response time (excluding the replica and average columns)
plt.figure(figsize=(10, 6))
for replica in range(30):
    plt.plot(range(1, 1 + len(response_values.iloc[replica])), response_values.iloc[replica], marker='o', label=f'Replica {replica+1}')

# Add labels and title
plt.xlabel('Request')
plt.ylabel('Response Time')
plt.title('Response Time for Each Request and Replica')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
